# %% [markdown]
# ### Código para dividir etiquetar las images

# %%
# Librerías necesarias
import cv2
import os
import pathlib
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import image

# %%
path = 'fruit_dataset/test'
training_set = os.listdir(path)

# %%
# Definimos un array de ceros con numpy con la capacidad 
# de set de entrenamiento
labels = np.zeros((len(training_set)), dtype=int)

# %%
# Cambiamos al directorio definido (path)
os.chdir(path)

# %%
# Proceso de etiquetado
len(training_set)
print('classifying images... (1) Manzana (2) Platano (3) Guayaba (4) Limón (5) Granada (6) Naranja')
for i in range(len(training_set)):
    img = cv2.imread(training_set[i])
    title_window = "imagen "+str(i)+'/'+str(len(training_set))
    cv2.putText(img=img, text=title_window, org=(10, 10), fontFace=cv2.FONT_HERSHEY_DUPLEX, fontScale=.4, color=(0, 255,0), thickness=1)
    cv2.imshow('labeler', img)
    cv2.moveWindow('labeler', 40,30)

    k = cv2.waitKey(0)

    if k == 49: 
        labels[i]=1
    elif k == 50:
        labels[i]=2
    elif k == 51:
        labels[i]=3
    elif k == 52:
        labels[i]=4
    elif k == 53:
        labels[i]=5
    elif k == 54:
        labels[i]=6
    else:
        # Detectar incorrectos en el txt
        labels[i]=-1
    print(training_set[i] +' has ben classified as: ('+ str(labels[i])+')')

cv2.destroyAllWindows()
print(labels)
txt_name = 'labels_test.txt'
print('saving data on: '+ path + ' as ' + txt_name )
np.savetxt(txt_name,labels,fmt='%d')
# Out:
# classifying images... (1) Manzana (2) Platano (3) Guayaba (4) Limón (5) Granada (6) Naranja
# fruit_100.jpg has ben classified as: (1)
# fruit_1000.jpg has ben classified as: (6)
# fruit_102.jpg has ben classified as: (3)
# fruit_104.jpg has ben classified as: (4)
# fruit_113.jpg has ben classified as: (6)
# fruit_114.jpg has ben classified as: (2)
# fruit_12.jpg has ben classified as: (5)
# fruit_128.jpg has ben classified as: (6)
# fruit_135.jpg has ben classified as: (4)
# fruit_136.jpg has ben classified as: (2)
# fruit_137.jpg has ben classified as: (5)
# fruit_143.jpg has ben classified as: (4)
# fruit_149.jpg has ben classified as: (3)
# fruit_155.jpg has ben classified as: (3)
# fruit_158.jpg has ben classified as: (1)
# fruit_160.jpg has ben classified as: (1)
# fruit_163.jpg has ben classified as: (1)
# fruit_166.jpg has ben classified as: (3)
# fruit_170.jpg has ben classified as: (3)
# fruit_178.jpg has ben classified as: (1)
# fruit_18.jpg has ben classified as: (3)
# fruit_180.jpg has ben classified as: (1)
# fruit_181.jpg has ben classified as: (2)
# fruit_184.jpg has ben classified as: (3)
# fruit_186.jpg has ben classified as: (5)
# fruit_189.jpg has ben classified as: (6)
# fruit_19.jpg has ben classified as: (4)
# fruit_193.jpg has ben classified as: (3)
# fruit_194.jpg has ben classified as: (2)
# fruit_210.jpg has ben classified as: (4)
# fruit_213.jpg has ben classified as: (2)
# fruit_214.jpg has ben classified as: (3)
# fruit_221.jpg has ben classified as: (2)
# fruit_229.jpg has ben classified as: (5)
# fruit_238.jpg has ben classified as: (3)
# fruit_240.jpg has ben classified as: (5)
# fruit_247.jpg has ben classified as: (6)
# fruit_251.jpg has ben classified as: (2)
# fruit_252.jpg has ben classified as: (4)
# fruit_258.jpg has ben classified as: (1)
# fruit_26.jpg has ben classified as: (3)
# fruit_267.jpg has ben classified as: (4)
# fruit_269.jpg has ben classified as: (3)
# fruit_270.jpg has ben classified as: (5)
# fruit_275.jpg has ben classified as: (1)
# fruit_278.jpg has ben classified as: (1)
# fruit_284.jpg has ben classified as: (3)
# fruit_290.jpg has ben classified as: (4)
# fruit_291.jpg has ben classified as: (1)
# fruit_295.jpg has ben classified as: (2)
# fruit_298.jpg has ben classified as: (5)
# fruit_299.jpg has ben classified as: (1)
# fruit_31.jpg has ben classified as: (2)
# fruit_316.jpg has ben classified as: (3)
# fruit_330.jpg has ben classified as: (1)
# fruit_332.jpg has ben classified as: (6)
# fruit_334.jpg has ben classified as: (3)
# fruit_346.jpg has ben classified as: (1)
# fruit_352.jpg has ben classified as: (5)
# fruit_36.jpg has ben classified as: (2)
# fruit_37.jpg has ben classified as: (4)
# fruit_370.jpg has ben classified as: (5)
# fruit_376.jpg has ben classified as: (3)
# fruit_387.jpg has ben classified as: (3)
# fruit_393.jpg has ben classified as: (3)
# fruit_40.jpg has ben classified as: (3)
# fruit_404.jpg has ben classified as: (5)
# fruit_405.jpg has ben classified as: (3)
# fruit_407.jpg has ben classified as: (3)
# fruit_408.jpg has ben classified as: (5)
# fruit_410.jpg has ben classified as: (2)
# fruit_421.jpg has ben classified as: (6)
# fruit_431.jpg has ben classified as: (1)
# fruit_433.jpg has ben classified as: (2)
# fruit_435.jpg has ben classified as: (4)
# fruit_445.jpg has ben classified as: (1)
# fruit_449.jpg has ben classified as: (5)
# fruit_454.jpg has ben classified as: (1)
# fruit_459.jpg has ben classified as: (5)
# fruit_462.jpg has ben classified as: (2)
# fruit_467.jpg has ben classified as: (2)
# fruit_477.jpg has ben classified as: (1)
# fruit_481.jpg has ben classified as: (3)
# fruit_482.jpg has ben classified as: (5)
# fruit_485.jpg has ben classified as: (6)
# fruit_486.jpg has ben classified as: (4)
# fruit_490.jpg has ben classified as: (4)
# fruit_491.jpg has ben classified as: (2)
# fruit_497.jpg has ben classified as: (1)
# fruit_499.jpg has ben classified as: (4)
# fruit_502.jpg has ben classified as: (3)
# fruit_512.jpg has ben classified as: (1)
# fruit_514.jpg has ben classified as: (1)
# fruit_516.jpg has ben classified as: (2)
# fruit_517.jpg has ben classified as: (1)
# fruit_518.jpg has ben classified as: (3)
# fruit_525.jpg has ben classified as: (4)
# fruit_526.jpg has ben classified as: (2)
# fruit_534.jpg has ben classified as: (3)
# fruit_536.jpg has ben classified as: (5)
# fruit_539.jpg has ben classified as: (4)
# fruit_54.jpg has ben classified as: (3)
# fruit_541.jpg has ben classified as: (6)
# fruit_544.jpg has ben classified as: (5)
# fruit_548.jpg has ben classified as: (6)
# fruit_551.jpg has ben classified as: (4)
# fruit_554.jpg has ben classified as: (3)
# fruit_555.jpg has ben classified as: (6)
# fruit_557.jpg has ben classified as: (2)
# fruit_558.jpg has ben classified as: (3)
# fruit_56.jpg has ben classified as: (2)
# fruit_560.jpg has ben classified as: (3)
# fruit_569.jpg has ben classified as: (1)
# fruit_571.jpg has ben classified as: (6)
# fruit_575.jpg has ben classified as: (4)
# fruit_588.jpg has ben classified as: (6)
# fruit_593.jpg has ben classified as: (5)
# fruit_597.jpg has ben classified as: (3)
# fruit_603.jpg has ben classified as: (6)
# fruit_605.jpg has ben classified as: (1)
# fruit_607.jpg has ben classified as: (4)
# fruit_608.jpg has ben classified as: (2)
# fruit_612.jpg has ben classified as: (2)
# fruit_618.jpg has ben classified as: (5)
# fruit_624.jpg has ben classified as: (2)
# fruit_63.jpg has ben classified as: (4)
# fruit_632.jpg has ben classified as: (4)
# fruit_633.jpg has ben classified as: (2)
# fruit_634.jpg has ben classified as: (3)
# fruit_644.jpg has ben classified as: (5)
# fruit_651.jpg has ben classified as: (3)
# fruit_653.jpg has ben classified as: (4)
# fruit_659.jpg has ben classified as: (5)
# fruit_66.jpg has ben classified as: (2)
# fruit_662.jpg has ben classified as: (2)
# fruit_663.jpg has ben classified as: (5)
# fruit_665.jpg has ben classified as: (4)
# fruit_673.jpg has ben classified as: (6)
# fruit_675.jpg has ben classified as: (4)
# fruit_688.jpg has ben classified as: (3)
# fruit_70.jpg has ben classified as: (1)
# fruit_701.jpg has ben classified as: (4)
# fruit_703.jpg has ben classified as: (1)
# fruit_721.jpg has ben classified as: (6)
# fruit_724.jpg has ben classified as: (5)
# fruit_725.jpg has ben classified as: (4)
# fruit_727.jpg has ben classified as: (1)
# fruit_733.jpg has ben classified as: (3)
# fruit_735.jpg has ben classified as: (4)
# fruit_736.jpg has ben classified as: (6)
# fruit_742.jpg has ben classified as: (3)
# fruit_744.jpg has ben classified as: (3)
# fruit_748.jpg has ben classified as: (3)
# fruit_756.jpg has ben classified as: (5)
# fruit_760.jpg has ben classified as: (5)
# fruit_764.jpg has ben classified as: (4)
# fruit_772.jpg has ben classified as: (5)
# fruit_784.jpg has ben classified as: (6)
# fruit_787.jpg has ben classified as: (6)
# fruit_794.jpg has ben classified as: (1)
# fruit_795.jpg has ben classified as: (4)
# fruit_797.jpg has ben classified as: (6)
# fruit_804.jpg has ben classified as: (3)
# fruit_811.jpg has ben classified as: (4)
# fruit_815.jpg has ben classified as: (3)
# fruit_818.jpg has ben classified as: (2)
# fruit_82.jpg has ben classified as: (6)
# fruit_829.jpg has ben classified as: (6)
# fruit_83.jpg has ben classified as: (6)
# fruit_830.jpg has ben classified as: (3)
# fruit_832.jpg has ben classified as: (4)
# fruit_838.jpg has ben classified as: (4)
# fruit_859.jpg has ben classified as: (2)
# fruit_862.jpg has ben classified as: (6)
# fruit_87.jpg has ben classified as: (6)
# fruit_871.jpg has ben classified as: (3)
# fruit_876.jpg has ben classified as: (4)
# fruit_88.jpg has ben classified as: (4)
# fruit_882.jpg has ben classified as: (5)
# fruit_883.jpg has ben classified as: (4)
# fruit_888.jpg has ben classified as: (2)
# fruit_891.jpg has ben classified as: (2)
# fruit_896.jpg has ben classified as: (6)
# fruit_897.jpg has ben classified as: (2)
# fruit_918.jpg has ben classified as: (3)
# fruit_920.jpg has ben classified as: (5)
# fruit_921.jpg has ben classified as: (2)
# fruit_927.jpg has ben classified as: (6)
# fruit_93.jpg has ben classified as: (3)
# fruit_930.jpg has ben classified as: (4)
# fruit_932.jpg has ben classified as: (1)
# fruit_933.jpg has ben classified as: (3)
# fruit_942.jpg has ben classified as: (2)
# fruit_955.jpg has ben classified as: (4)
# fruit_960.jpg has ben classified as: (2)
# fruit_964.jpg has ben classified as: (2)
# fruit_969.jpg has ben classified as: (3)
# fruit_981.jpg has ben classified as: (1)
# fruit_985.jpg has ben classified as: (4)
# fruit_989.jpg has ben classified as: (5)
# fruit_992.jpg has ben classified as: (4)
# fruit_997.jpg has ben classified as: (2)
# [1 6 3 4 6 2 5 6 4 2 5 4 3 3 1 1 1 3 3 1 3 1 2 3 5 6 4 3 2 4 2 3 2 5 3 5 6
#  2 4 1 3 4 3 5 1 1 3 4 1 2 5 1 2 3 1 6 3 1 5 2 4 5 3 3 3 3 5 3 3 5 2 6 1 2
#  4 1 5 1 5 2 2 1 3 5 6 4 4 2 1 4 3 1 1 2 1 3 4 2 3 5 4 3 6 5 6 4 3 6 2 3 2
#  3 1 6 4 6 5 3 6 1 4 2 2 5 2 4 4 2 3 5 3 4 5 2 2 5 4 6 4 3 1 4 1 6 5 4 1 3
#  4 6 3 3 3 5 5 4 5 6 6 1 4 6 3 4 3 2 6 6 6 3 4 4 2 6 6 3 4 4 5 4 2 2 6 2 3
#  5 2 6 3 4 1 3 2 4 2 2 3 1 4 5 4 2]
# saving data on: fruit_dataset/test as labels_test.txt
