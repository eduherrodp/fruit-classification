# %%
import os
import glob
from PIL import Image, ImageDraw, ImageFilter

# %%
def crop_center(pil_img, crop_width, crop_height):
    img_width, img_height = pil_img.size
    return pil_img.crop(((img_width - crop_width) // 2,
                         (img_height - crop_height) // 2,
                         (img_width + crop_width) // 2,
                         (img_height + crop_height) // 2))
def crop_max_square(pil_img):
    return crop_center(pil_img, min(pil_img.size), min(pil_img.size))

# %%
path = os.getcwd()+'\\fruit_dataset'
print(path)
# Out:
# A:\Fruit-Classification\fruit_dataset

# %%
thumb_width = 256

# %%
# Obtenemos el directorio de las carpetas
list = os.listdir(path)

# %%
for i in range(len(list)):
    # Obtenemos la lista de imagenes de cada carpeta
    images =  os.listdir(path+'\\'+list[i])
    # Nos movemos al directorio (solo ejecutar una vez)
    os.chdir(path+'\\'+list[i])
    for j in range (len(images)):
            im = Image.open(images[j])
            print("recortando: "+images[j]+"ruta: "+list[i])
            im_thumb = crop_max_square(im).resize((thumb_width, thumb_width), Image.LANCZOS)
            
            im_thumb.save(images[j], quality=95)

        # Regresamos a la carpeta de origen
    os.chdir(path)

print("Proceso de renombrado correcto :)")
print(images)
# Out:
# recortando: fruit_100.jpgruta: test
# recortando: fruit_1000.jpgruta: test
# recortando: fruit_102.jpgruta: test
# recortando: fruit_104.jpgruta: test
# recortando: fruit_113.jpgruta: test
# recortando: fruit_114.jpgruta: test
# recortando: fruit_12.jpgruta: test
# recortando: fruit_128.jpgruta: test
# recortando: fruit_135.jpgruta: test
# recortando: fruit_136.jpgruta: test
# recortando: fruit_137.jpgruta: test
# recortando: fruit_143.jpgruta: test
# recortando: fruit_149.jpgruta: test
# recortando: fruit_155.jpgruta: test
# recortando: fruit_158.jpgruta: test
# recortando: fruit_160.jpgruta: test
# recortando: fruit_163.jpgruta: test
# recortando: fruit_166.jpgruta: test
# recortando: fruit_170.jpgruta: test
# recortando: fruit_178.jpgruta: test
# recortando: fruit_18.jpgruta: test
# recortando: fruit_180.jpgruta: test
# recortando: fruit_181.jpgruta: test
# recortando: fruit_184.jpgruta: test
# recortando: fruit_186.jpgruta: test
# recortando: fruit_189.jpgruta: test
# recortando: fruit_19.jpgruta: test
# recortando: fruit_193.jpgruta: test
# recortando: fruit_194.jpgruta: test
# recortando: fruit_210.jpgruta: test
# recortando: fruit_213.jpgruta: test
# recortando: fruit_214.jpgruta: test
# recortando: fruit_221.jpgruta: test
# recortando: fruit_229.jpgruta: test
# recortando: fruit_238.jpgruta: test
# recortando: fruit_240.jpgruta: test
# recortando: fruit_247.jpgruta: test
# recortando: fruit_251.jpgruta: test
# recortando: fruit_252.jpgruta: test
# recortando: fruit_258.jpgruta: test
# recortando: fruit_26.jpgruta: test
# recortando: fruit_267.jpgruta: test
# recortando: fruit_269.jpgruta: test
# recortando: fruit_270.jpgruta: test
# recortando: fruit_275.jpgruta: test
# recortando: fruit_278.jpgruta: test
# recortando: fruit_284.jpgruta: test
# recortando: fruit_290.jpgruta: test
# recortando: fruit_291.jpgruta: test
# recortando: fruit_295.jpgruta: test
# recortando: fruit_298.jpgruta: test
# recortando: fruit_299.jpgruta: test
# recortando: fruit_31.jpgruta: test
# recortando: fruit_316.jpgruta: test
# recortando: fruit_330.jpgruta: test
# recortando: fruit_332.jpgruta: test
# recortando: fruit_334.jpgruta: test
# recortando: fruit_346.jpgruta: test
# recortando: fruit_352.jpgruta: test
# recortando: fruit_36.jpgruta: test
# recortando: fruit_37.jpgruta: test
# recortando: fruit_370.jpgruta: test
# recortando: fruit_376.jpgruta: test
# recortando: fruit_387.jpgruta: test
# recortando: fruit_393.jpgruta: test
# recortando: fruit_40.jpgruta: test
# recortando: fruit_404.jpgruta: test
# recortando: fruit_405.jpgruta: test
# recortando: fruit_407.jpgruta: test
# recortando: fruit_408.jpgruta: test
# recortando: fruit_410.jpgruta: test
# recortando: fruit_421.jpgruta: test
# recortando: fruit_431.jpgruta: test
# recortando: fruit_433.jpgruta: test
# recortando: fruit_435.jpgruta: test
# recortando: fruit_445.jpgruta: test
# recortando: fruit_449.jpgruta: test
# recortando: fruit_454.jpgruta: test
# recortando: fruit_459.jpgruta: test
# recortando: fruit_462.jpgruta: test
# recortando: fruit_467.jpgruta: test
# recortando: fruit_477.jpgruta: test
# recortando: fruit_481.jpgruta: test
# recortando: fruit_482.jpgruta: test
# recortando: fruit_485.jpgruta: test
# recortando: fruit_486.jpgruta: test
# recortando: fruit_490.jpgruta: test
# recortando: fruit_491.jpgruta: test
# recortando: fruit_497.jpgruta: test
# recortando: fruit_499.jpgruta: test
# recortando: fruit_502.jpgruta: test
# recortando: fruit_512.jpgruta: test
# recortando: fruit_514.jpgruta: test
# recortando: fruit_516.jpgruta: test
# recortando: fruit_517.jpgruta: test
# recortando: fruit_518.jpgruta: test
# recortando: fruit_525.jpgruta: test
# recortando: fruit_526.jpgruta: test
# recortando: fruit_534.jpgruta: test
# recortando: fruit_536.jpgruta: test
# recortando: fruit_539.jpgruta: test
# recortando: fruit_54.jpgruta: test
# recortando: fruit_541.jpgruta: test
# recortando: fruit_544.jpgruta: test
# recortando: fruit_548.jpgruta: test
# recortando: fruit_551.jpgruta: test
# recortando: fruit_554.jpgruta: test
# recortando: fruit_555.jpgruta: test
# recortando: fruit_557.jpgruta: test
# recortando: fruit_558.jpgruta: test
# recortando: fruit_56.jpgruta: test
# recortando: fruit_560.jpgruta: test
# recortando: fruit_569.jpgruta: test
# recortando: fruit_571.jpgruta: test
# recortando: fruit_575.jpgruta: test
# recortando: fruit_588.jpgruta: test
# recortando: fruit_593.jpgruta: test
# recortando: fruit_597.jpgruta: test
# recortando: fruit_603.jpgruta: test
# recortando: fruit_605.jpgruta: test
# recortando: fruit_607.jpgruta: test
# recortando: fruit_608.jpgruta: test
# recortando: fruit_612.jpgruta: test
# recortando: fruit_618.jpgruta: test
# recortando: fruit_624.jpgruta: test
# recortando: fruit_63.jpgruta: test
# recortando: fruit_632.jpgruta: test
# recortando: fruit_633.jpgruta: test
# recortando: fruit_634.jpgruta: test
# recortando: fruit_644.jpgruta: test
# recortando: fruit_651.jpgruta: test
# recortando: fruit_653.jpgruta: test
# recortando: fruit_659.jpgruta: test
# recortando: fruit_66.jpgruta: test
# recortando: fruit_662.jpgruta: test
# recortando: fruit_663.jpgruta: test
# recortando: fruit_665.jpgruta: test
# recortando: fruit_673.jpgruta: test
# recortando: fruit_675.jpgruta: test
# recortando: fruit_688.jpgruta: test
# recortando: fruit_70.jpgruta: test
# recortando: fruit_701.jpgruta: test
# recortando: fruit_703.jpgruta: test
# recortando: fruit_721.jpgruta: test
# recortando: fruit_724.jpgruta: test
# recortando: fruit_725.jpgruta: test
# recortando: fruit_727.jpgruta: test
# recortando: fruit_733.jpgruta: test
# recortando: fruit_735.jpgruta: test
# recortando: fruit_736.jpgruta: test
# recortando: fruit_742.jpgruta: test
# recortando: fruit_744.jpgruta: test
# recortando: fruit_748.jpgruta: test
# recortando: fruit_756.jpgruta: test
# recortando: fruit_760.jpgruta: test
# recortando: fruit_764.jpgruta: test
# recortando: fruit_772.jpgruta: test
# recortando: fruit_784.jpgruta: test
# recortando: fruit_787.jpgruta: test
# recortando: fruit_794.jpgruta: test
# recortando: fruit_795.jpgruta: test
# recortando: fruit_797.jpgruta: test
# recortando: fruit_804.jpgruta: test
# recortando: fruit_811.jpgruta: test
# recortando: fruit_815.jpgruta: test
# recortando: fruit_818.jpgruta: test
# recortando: fruit_82.jpgruta: test
# recortando: fruit_829.jpgruta: test
# recortando: fruit_83.jpgruta: test
# recortando: fruit_830.jpgruta: test
# recortando: fruit_832.jpgruta: test
# recortando: fruit_838.jpgruta: test
# recortando: fruit_859.jpgruta: test
# recortando: fruit_862.jpgruta: test
# recortando: fruit_87.jpgruta: test
# recortando: fruit_871.jpgruta: test
# recortando: fruit_876.jpgruta: test
# recortando: fruit_88.jpgruta: test
# recortando: fruit_882.jpgruta: test
# recortando: fruit_883.jpgruta: test
# recortando: fruit_888.jpgruta: test
# recortando: fruit_891.jpgruta: test
# recortando: fruit_896.jpgruta: test
# recortando: fruit_897.jpgruta: test
# recortando: fruit_918.jpgruta: test
# recortando: fruit_920.jpgruta: test
# recortando: fruit_921.jpgruta: test
# recortando: fruit_927.jpgruta: test
# recortando: fruit_93.jpgruta: test
# recortando: fruit_930.jpgruta: test
# recortando: fruit_932.jpgruta: test
# recortando: fruit_933.jpgruta: test
# recortando: fruit_942.jpgruta: test
# recortando: fruit_955.jpgruta: test
# recortando: fruit_960.jpgruta: test
# recortando: fruit_964.jpgruta: test
# recortando: fruit_969.jpgruta: test
# recortando: fruit_981.jpgruta: test
# recortando: fruit_985.jpgruta: test
# recortando: fruit_989.jpgruta: test
# recortando: fruit_992.jpgruta: test
# recortando: fruit_997.jpgruta: test
# recortando: fruit_1.jpgruta: training
# recortando: fruit_10.jpgruta: training
# recortando: fruit_1001.jpgruta: training
# recortando: fruit_1002.jpgruta: training
# recortando: fruit_101.jpgruta: training
# recortando: fruit_103.jpgruta: training
# recortando: fruit_105.jpgruta: training
# recortando: fruit_106.jpgruta: training
# recortando: fruit_107.jpgruta: training
# recortando: fruit_108.jpgruta: training
# recortando: fruit_109.jpgruta: training
# recortando: fruit_11.jpgruta: training
# recortando: fruit_110.jpgruta: training
# recortando: fruit_111.jpgruta: training
# recortando: fruit_112.jpgruta: training
# recortando: fruit_115.jpgruta: training
# recortando: fruit_116.jpgruta: training
# recortando: fruit_117.jpgruta: training
# recortando: fruit_118.jpgruta: training
# recortando: fruit_119.jpgruta: training
# recortando: fruit_120.jpgruta: training
# recortando: fruit_121.jpgruta: training
# recortando: fruit_122.jpgruta: training
# recortando: fruit_123.jpgruta: training
# recortando: fruit_124.jpgruta: training
# recortando: fruit_125.jpgruta: training
# recortando: fruit_126.jpgruta: training
# recortando: fruit_127.jpgruta: training
# recortando: fruit_129.jpgruta: training
# recortando: fruit_13.jpgruta: training
# recortando: fruit_130.jpgruta: training
# recortando: fruit_131.jpgruta: training
# recortando: fruit_132.jpgruta: training
# recortando: fruit_133.jpgruta: training
# recortando: fruit_134.jpgruta: training
# recortando: fruit_138.jpgruta: training
# recortando: fruit_139.jpgruta: training
# recortando: fruit_14.jpgruta: training
# recortando: fruit_140.jpgruta: training
# recortando: fruit_141.jpgruta: training
# recortando: fruit_142.jpgruta: training
# recortando: fruit_144.jpgruta: training
# recortando: fruit_145.jpgruta: training
# recortando: fruit_146.jpgruta: training
# recortando: fruit_147.jpgruta: training
# recortando: fruit_148.jpgruta: training
# recortando: fruit_15.jpgruta: training
# recortando: fruit_150.jpgruta: training
# recortando: fruit_151.jpgruta: training
# recortando: fruit_152.jpgruta: training
# recortando: fruit_153.jpgruta: training
# recortando: fruit_154.jpgruta: training
# recortando: fruit_156.jpgruta: training
# recortando: fruit_157.jpgruta: training
# recortando: fruit_159.jpgruta: training
# recortando: fruit_16.jpgruta: training
# recortando: fruit_161.jpgruta: training
# recortando: fruit_162.jpgruta: training
# recortando: fruit_164.jpgruta: training
# recortando: fruit_165.jpgruta: training
# recortando: fruit_167.jpgruta: training
# recortando: fruit_168.jpgruta: training
# recortando: fruit_169.jpgruta: training
# recortando: fruit_17.jpgruta: training
# recortando: fruit_171.jpgruta: training
# recortando: fruit_172.jpgruta: training
# recortando: fruit_173.jpgruta: training
# recortando: fruit_174.jpgruta: training
# recortando: fruit_175.jpgruta: training
# recortando: fruit_176.jpgruta: training
# recortando: fruit_177.jpgruta: training
# recortando: fruit_179.jpgruta: training
# recortando: fruit_182.jpgruta: training
# recortando: fruit_183.jpgruta: training
# recortando: fruit_185.jpgruta: training
# recortando: fruit_187.jpgruta: training
# recortando: fruit_188.jpgruta: training
# recortando: fruit_190.jpgruta: training
# recortando: fruit_191.jpgruta: training
# recortando: fruit_192.jpgruta: training
# recortando: fruit_195.jpgruta: training
# recortando: fruit_196.jpgruta: training
# recortando: fruit_197.jpgruta: training
# recortando: fruit_198.jpgruta: training
# recortando: fruit_199.jpgruta: training
# recortando: fruit_2.jpgruta: training
# recortando: fruit_20.jpgruta: training
# recortando: fruit_200.jpgruta: training
# recortando: fruit_201.jpgruta: training
# recortando: fruit_202.jpgruta: training
# recortando: fruit_203.jpgruta: training
# recortando: fruit_204.jpgruta: training
# recortando: fruit_205.jpgruta: training
# recortando: fruit_206.jpgruta: training
# recortando: fruit_207.jpgruta: training
# recortando: fruit_208.jpgruta: training
# recortando: fruit_209.jpgruta: training
# recortando: fruit_21.jpgruta: training
# recortando: fruit_211.jpgruta: training
# recortando: fruit_212.jpgruta: training
# recortando: fruit_215.jpgruta: training
# recortando: fruit_216.jpgruta: training
# recortando: fruit_217.jpgruta: training
# recortando: fruit_218.jpgruta: training
# recortando: fruit_219.jpgruta: training
# recortando: fruit_22.jpgruta: training
# recortando: fruit_220.jpgruta: training
# recortando: fruit_222.jpgruta: training
# recortando: fruit_223.jpgruta: training
# recortando: fruit_224.jpgruta: training
# recortando: fruit_225.jpgruta: training
# recortando: fruit_226.jpgruta: training
# recortando: fruit_227.jpgruta: training
# recortando: fruit_228.jpgruta: training
# recortando: fruit_23.jpgruta: training
# recortando: fruit_230.jpgruta: training
# recortando: fruit_231.jpgruta: training
# recortando: fruit_232.jpgruta: training
# recortando: fruit_233.jpgruta: training
# recortando: fruit_234.jpgruta: training
# recortando: fruit_235.jpgruta: training
# recortando: fruit_236.jpgruta: training
# recortando: fruit_237.jpgruta: training
# recortando: fruit_239.jpgruta: training
# recortando: fruit_24.jpgruta: training
# recortando: fruit_241.jpgruta: training
# recortando: fruit_242.jpgruta: training
# recortando: fruit_243.jpgruta: training
# recortando: fruit_244.jpgruta: training
# recortando: fruit_245.jpgruta: training
# recortando: fruit_246.jpgruta: training
# recortando: fruit_248.jpgruta: training
# recortando: fruit_249.jpgruta: training
# recortando: fruit_25.jpgruta: training
# recortando: fruit_250.jpgruta: training
# recortando: fruit_253.jpgruta: training
# recortando: fruit_254.jpgruta: training
# recortando: fruit_255.jpgruta: training
# recortando: fruit_256.jpgruta: training
# recortando: fruit_257.jpgruta: training
# recortando: fruit_259.jpgruta: training
# recortando: fruit_260.jpgruta: training
# recortando: fruit_261.jpgruta: training
# recortando: fruit_262.jpgruta: training
# recortando: fruit_263.jpgruta: training
# recortando: fruit_264.jpgruta: training
# recortando: fruit_265.jpgruta: training
# recortando: fruit_266.jpgruta: training
# recortando: fruit_268.jpgruta: training
# recortando: fruit_27.jpgruta: training
# recortando: fruit_271.jpgruta: training
# recortando: fruit_272.jpgruta: training
# recortando: fruit_273.jpgruta: training
# recortando: fruit_274.jpgruta: training
# recortando: fruit_276.jpgruta: training
# recortando: fruit_277.jpgruta: training
# recortando: fruit_279.jpgruta: training
# recortando: fruit_28.jpgruta: training
# recortando: fruit_280.jpgruta: training
# recortando: fruit_281.jpgruta: training
# recortando: fruit_282.jpgruta: training
# recortando: fruit_283.jpgruta: training
# recortando: fruit_285.jpgruta: training
# recortando: fruit_286.jpgruta: training
# recortando: fruit_287.jpgruta: training
# recortando: fruit_288.jpgruta: training
# recortando: fruit_289.jpgruta: training
# recortando: fruit_29.jpgruta: training
# recortando: fruit_292.jpgruta: training
# recortando: fruit_293.jpgruta: training
# recortando: fruit_294.jpgruta: training
# recortando: fruit_296.jpgruta: training
# recortando: fruit_297.jpgruta: training
# recortando: fruit_3.jpgruta: training
# recortando: fruit_30.jpgruta: training
# recortando: fruit_300.jpgruta: training
# recortando: fruit_301.jpgruta: training
# recortando: fruit_302.jpgruta: training
# recortando: fruit_303.jpgruta: training
# recortando: fruit_304.jpgruta: training
# recortando: fruit_305.jpgruta: training
# recortando: fruit_306.jpgruta: training
# recortando: fruit_307.jpgruta: training
# recortando: fruit_308.jpgruta: training
# recortando: fruit_309.jpgruta: training
# recortando: fruit_310.jpgruta: training
# recortando: fruit_311.jpgruta: training
# recortando: fruit_312.jpgruta: training
# recortando: fruit_313.jpgruta: training
# recortando: fruit_314.jpgruta: training
# recortando: fruit_315.jpgruta: training
# recortando: fruit_317.jpgruta: training
# recortando: fruit_318.jpgruta: training
# recortando: fruit_319.jpgruta: training
# recortando: fruit_32.jpgruta: training
# recortando: fruit_320.jpgruta: training
# recortando: fruit_321.jpgruta: training
# recortando: fruit_322.jpgruta: training
# recortando: fruit_323.jpgruta: training
# recortando: fruit_324.jpgruta: training
# recortando: fruit_325.jpgruta: training
# recortando: fruit_326.jpgruta: training
# recortando: fruit_327.jpgruta: training
# recortando: fruit_328.jpgruta: training
# recortando: fruit_329.jpgruta: training
# recortando: fruit_33.jpgruta: training
# recortando: fruit_331.jpgruta: training
# recortando: fruit_333.jpgruta: training
# recortando: fruit_335.jpgruta: training
# recortando: fruit_336.jpgruta: training
# recortando: fruit_337.jpgruta: training
# recortando: fruit_338.jpgruta: training
# recortando: fruit_339.jpgruta: training
# recortando: fruit_34.jpgruta: training
# recortando: fruit_340.jpgruta: training
# recortando: fruit_341.jpgruta: training
# recortando: fruit_342.jpgruta: training
# recortando: fruit_343.jpgruta: training
# recortando: fruit_344.jpgruta: training
# recortando: fruit_345.jpgruta: training
# recortando: fruit_347.jpgruta: training
# recortando: fruit_348.jpgruta: training
# recortando: fruit_349.jpgruta: training
# recortando: fruit_35.jpgruta: training
# recortando: fruit_350.jpgruta: training
# recortando: fruit_351.jpgruta: training
# recortando: fruit_353.jpgruta: training
# recortando: fruit_354.jpgruta: training
# recortando: fruit_355.jpgruta: training
# recortando: fruit_356.jpgruta: training
# recortando: fruit_357.jpgruta: training
# recortando: fruit_358.jpgruta: training
# recortando: fruit_359.jpgruta: training
# recortando: fruit_360.jpgruta: training
# recortando: fruit_361.jpgruta: training
# recortando: fruit_362.jpgruta: training
# recortando: fruit_363.jpgruta: training
# recortando: fruit_364.jpgruta: training
# recortando: fruit_365.jpgruta: training
# recortando: fruit_366.jpgruta: training
# recortando: fruit_367.jpgruta: training
# recortando: fruit_368.jpgruta: training
# recortando: fruit_369.jpgruta: training
# recortando: fruit_371.jpgruta: training
# recortando: fruit_372.jpgruta: training
# recortando: fruit_373.jpgruta: training
# recortando: fruit_374.jpgruta: training
# recortando: fruit_375.jpgruta: training
# recortando: fruit_377.jpgruta: training
# recortando: fruit_378.jpgruta: training
# recortando: fruit_379.jpgruta: training
# recortando: fruit_38.jpgruta: training
# recortando: fruit_380.jpgruta: training
# recortando: fruit_381.jpgruta: training
# recortando: fruit_382.jpgruta: training
# recortando: fruit_383.jpgruta: training
# recortando: fruit_384.jpgruta: training
# recortando: fruit_385.jpgruta: training
# recortando: fruit_386.jpgruta: training
# recortando: fruit_388.jpgruta: training
# recortando: fruit_389.jpgruta: training
# recortando: fruit_39.jpgruta: training
# recortando: fruit_390.jpgruta: training
# recortando: fruit_391.jpgruta: training
# recortando: fruit_392.jpgruta: training
# recortando: fruit_394.jpgruta: training
# recortando: fruit_395.jpgruta: training
# recortando: fruit_396.jpgruta: training
# recortando: fruit_397.jpgruta: training
# recortando: fruit_398.jpgruta: training
# recortando: fruit_399.jpgruta: training
# recortando: fruit_4.jpgruta: training
# recortando: fruit_400.jpgruta: training
# recortando: fruit_401.jpgruta: training
# recortando: fruit_402.jpgruta: training
# recortando: fruit_403.jpgruta: training
# recortando: fruit_406.jpgruta: training
# recortando: fruit_409.jpgruta: training
# recortando: fruit_41.jpgruta: training
# recortando: fruit_411.jpgruta: training
# recortando: fruit_412.jpgruta: training
# recortando: fruit_413.jpgruta: training
# recortando: fruit_414.jpgruta: training
# recortando: fruit_415.jpgruta: training
# recortando: fruit_416.jpgruta: training
# recortando: fruit_417.jpgruta: training
# recortando: fruit_418.jpgruta: training
# recortando: fruit_419.jpgruta: training
# recortando: fruit_42.jpgruta: training
# recortando: fruit_420.jpgruta: training
# recortando: fruit_422.jpgruta: training
# recortando: fruit_423.jpgruta: training
# recortando: fruit_424.jpgruta: training
# recortando: fruit_425.jpgruta: training
# recortando: fruit_426.jpgruta: training
# recortando: fruit_427.jpgruta: training
# recortando: fruit_428.jpgruta: training
# recortando: fruit_429.jpgruta: training
# recortando: fruit_43.jpgruta: training
# recortando: fruit_430.jpgruta: training
# recortando: fruit_432.jpgruta: training
# recortando: fruit_434.jpgruta: training
# recortando: fruit_436.jpgruta: training
# recortando: fruit_437.jpgruta: training
# recortando: fruit_438.jpgruta: training
# recortando: fruit_439.jpgruta: training
# recortando: fruit_44.jpgruta: training
# recortando: fruit_440.jpgruta: training
# recortando: fruit_441.jpgruta: training
# recortando: fruit_442.jpgruta: training
# recortando: fruit_443.jpgruta: training
# recortando: fruit_444.jpgruta: training
# recortando: fruit_446.jpgruta: training
# recortando: fruit_447.jpgruta: training
# recortando: fruit_448.jpgruta: training
# recortando: fruit_45.jpgruta: training
# recortando: fruit_450.jpgruta: training
# recortando: fruit_451.jpgruta: training
# recortando: fruit_452.jpgruta: training
# recortando: fruit_453.jpgruta: training
# recortando: fruit_455.jpgruta: training
# recortando: fruit_456.jpgruta: training
# recortando: fruit_457.jpgruta: training
# recortando: fruit_458.jpgruta: training
# recortando: fruit_46.jpgruta: training
# recortando: fruit_460.jpgruta: training
# recortando: fruit_461.jpgruta: training
# recortando: fruit_463.jpgruta: training
# recortando: fruit_464.jpgruta: training
# recortando: fruit_465.jpgruta: training
# recortando: fruit_466.jpgruta: training
# recortando: fruit_468.jpgruta: training
# recortando: fruit_469.jpgruta: training
# recortando: fruit_47.jpgruta: training
# recortando: fruit_470.jpgruta: training
# recortando: fruit_471.jpgruta: training
# recortando: fruit_472.jpgruta: training
# recortando: fruit_473.jpgruta: training
# recortando: fruit_474.jpgruta: training
# recortando: fruit_475.jpgruta: training
# recortando: fruit_476.jpgruta: training
# recortando: fruit_478.jpgruta: training
# recortando: fruit_479.jpgruta: training
# recortando: fruit_48.jpgruta: training
# recortando: fruit_480.jpgruta: training
# recortando: fruit_483.jpgruta: training
# recortando: fruit_484.jpgruta: training
# recortando: fruit_487.jpgruta: training
# recortando: fruit_488.jpgruta: training
# recortando: fruit_489.jpgruta: training
# recortando: fruit_49.jpgruta: training
# recortando: fruit_492.jpgruta: training
# recortando: fruit_493.jpgruta: training
# recortando: fruit_494.jpgruta: training
# recortando: fruit_495.jpgruta: training
# recortando: fruit_496.jpgruta: training
# recortando: fruit_498.jpgruta: training
# recortando: fruit_5.jpgruta: training
# recortando: fruit_50.jpgruta: training
# recortando: fruit_500.jpgruta: training
# recortando: fruit_501.jpgruta: training
# recortando: fruit_503.jpgruta: training
# recortando: fruit_504.jpgruta: training
# recortando: fruit_505.jpgruta: training
# recortando: fruit_506.jpgruta: training
# recortando: fruit_507.jpgruta: training
# recortando: fruit_508.jpgruta: training
# recortando: fruit_509.jpgruta: training
# recortando: fruit_51.jpgruta: training
# recortando: fruit_510.jpgruta: training
# recortando: fruit_511.jpgruta: training
# recortando: fruit_513.jpgruta: training
# recortando: fruit_515.jpgruta: training
# recortando: fruit_519.jpgruta: training
# recortando: fruit_52.jpgruta: training
# recortando: fruit_520.jpgruta: training
# recortando: fruit_521.jpgruta: training
# recortando: fruit_522.jpgruta: training
# recortando: fruit_523.jpgruta: training
# recortando: fruit_524.jpgruta: training
# recortando: fruit_527.jpgruta: training
# recortando: fruit_528.jpgruta: training
# recortando: fruit_529.jpgruta: training
# recortando: fruit_53.jpgruta: training
# recortando: fruit_530.jpgruta: training
# recortando: fruit_531.jpgruta: training
# recortando: fruit_532.jpgruta: training
# recortando: fruit_533.jpgruta: training
# recortando: fruit_535.jpgruta: training
# recortando: fruit_537.jpgruta: training
# recortando: fruit_538.jpgruta: training
# recortando: fruit_540.jpgruta: training
# recortando: fruit_542.jpgruta: training
# recortando: fruit_543.jpgruta: training
# recortando: fruit_545.jpgruta: training
# recortando: fruit_546.jpgruta: training
# recortando: fruit_547.jpgruta: training
# recortando: fruit_549.jpgruta: training
# recortando: fruit_55.jpgruta: training
# recortando: fruit_550.jpgruta: training
# recortando: fruit_552.jpgruta: training
# recortando: fruit_553.jpgruta: training
# recortando: fruit_556.jpgruta: training
# recortando: fruit_559.jpgruta: training
# recortando: fruit_561.jpgruta: training
# recortando: fruit_562.jpgruta: training
# recortando: fruit_563.jpgruta: training
# recortando: fruit_564.jpgruta: training
# recortando: fruit_565.jpgruta: training
# recortando: fruit_566.jpgruta: training
# recortando: fruit_567.jpgruta: training
# recortando: fruit_568.jpgruta: training
# recortando: fruit_57.jpgruta: training
# recortando: fruit_570.jpgruta: training
# recortando: fruit_572.jpgruta: training
# recortando: fruit_573.jpgruta: training
# recortando: fruit_574.jpgruta: training
# recortando: fruit_576.jpgruta: training
# recortando: fruit_577.jpgruta: training
# recortando: fruit_578.jpgruta: training
# recortando: fruit_579.jpgruta: training
# recortando: fruit_58.jpgruta: training
# recortando: fruit_580.jpgruta: training
# recortando: fruit_581.jpgruta: training
# recortando: fruit_582.jpgruta: training
# recortando: fruit_583.jpgruta: training
# recortando: fruit_584.jpgruta: training
# recortando: fruit_585.jpgruta: training
# recortando: fruit_586.jpgruta: training
# recortando: fruit_587.jpgruta: training
# recortando: fruit_589.jpgruta: training
# recortando: fruit_59.jpgruta: training
# recortando: fruit_590.jpgruta: training
# recortando: fruit_591.jpgruta: training
# recortando: fruit_592.jpgruta: training
# recortando: fruit_594.jpgruta: training
# recortando: fruit_595.jpgruta: training
# recortando: fruit_596.jpgruta: training
# recortando: fruit_598.jpgruta: training
# recortando: fruit_599.jpgruta: training
# recortando: fruit_6.jpgruta: training
# recortando: fruit_60.jpgruta: training
# recortando: fruit_600.jpgruta: training
# recortando: fruit_601.jpgruta: training
# recortando: fruit_602.jpgruta: training
# recortando: fruit_604.jpgruta: training
# recortando: fruit_606.jpgruta: training
# recortando: fruit_609.jpgruta: training
# recortando: fruit_61.jpgruta: training
# recortando: fruit_610.jpgruta: training
# recortando: fruit_611.jpgruta: training
# recortando: fruit_613.jpgruta: training
# recortando: fruit_614.jpgruta: training
# recortando: fruit_615.jpgruta: training
# recortando: fruit_616.jpgruta: training
# recortando: fruit_617.jpgruta: training
# recortando: fruit_619.jpgruta: training
# recortando: fruit_62.jpgruta: training
# recortando: fruit_620.jpgruta: training
# recortando: fruit_621.jpgruta: training
# recortando: fruit_622.jpgruta: training
# recortando: fruit_623.jpgruta: training
# recortando: fruit_625.jpgruta: training
# recortando: fruit_626.jpgruta: training
# recortando: fruit_627.jpgruta: training
# recortando: fruit_628.jpgruta: training
# recortando: fruit_629.jpgruta: training
# recortando: fruit_630.jpgruta: training
# recortando: fruit_631.jpgruta: training
# recortando: fruit_635.jpgruta: training
# recortando: fruit_636.jpgruta: training
# recortando: fruit_637.jpgruta: training
# recortando: fruit_638.jpgruta: training
# recortando: fruit_639.jpgruta: training
# recortando: fruit_64.jpgruta: training
# recortando: fruit_640.jpgruta: training
# recortando: fruit_641.jpgruta: training
# recortando: fruit_642.jpgruta: training
# recortando: fruit_643.jpgruta: training
# recortando: fruit_645.jpgruta: training
# recortando: fruit_646.jpgruta: training
# recortando: fruit_647.jpgruta: training
# recortando: fruit_648.jpgruta: training
# recortando: fruit_649.jpgruta: training
# recortando: fruit_65.jpgruta: training
# recortando: fruit_650.jpgruta: training
# recortando: fruit_652.jpgruta: training
# recortando: fruit_654.jpgruta: training
# recortando: fruit_655.jpgruta: training
# recortando: fruit_656.jpgruta: training
# recortando: fruit_657.jpgruta: training
# recortando: fruit_658.jpgruta: training
# recortando: fruit_660.jpgruta: training
# recortando: fruit_661.jpgruta: training
# recortando: fruit_664.jpgruta: training
# recortando: fruit_666.jpgruta: training
# recortando: fruit_667.jpgruta: training
# recortando: fruit_668.jpgruta: training
# recortando: fruit_669.jpgruta: training
# recortando: fruit_67.jpgruta: training
# recortando: fruit_670.jpgruta: training
# recortando: fruit_671.jpgruta: training
# recortando: fruit_672.jpgruta: training
# recortando: fruit_674.jpgruta: training
# recortando: fruit_676.jpgruta: training
# recortando: fruit_677.jpgruta: training
# recortando: fruit_678.jpgruta: training
# recortando: fruit_679.jpgruta: training
# recortando: fruit_68.jpgruta: training
# recortando: fruit_680.jpgruta: training
# recortando: fruit_681.jpgruta: training
# recortando: fruit_682.jpgruta: training
# recortando: fruit_683.jpgruta: training
# recortando: fruit_684.jpgruta: training
# recortando: fruit_685.jpgruta: training
# recortando: fruit_686.jpgruta: training
# recortando: fruit_687.jpgruta: training
# recortando: fruit_689.jpgruta: training
# recortando: fruit_69.jpgruta: training
# recortando: fruit_690.jpgruta: training
# recortando: fruit_691.jpgruta: training
# recortando: fruit_692.jpgruta: training
# recortando: fruit_693.jpgruta: training
# recortando: fruit_694.jpgruta: training
# recortando: fruit_695.jpgruta: training
# recortando: fruit_696.jpgruta: training
# recortando: fruit_697.jpgruta: training
# recortando: fruit_698.jpgruta: training
# recortando: fruit_699.jpgruta: training
# recortando: fruit_7.jpgruta: training
# recortando: fruit_700.jpgruta: training
# recortando: fruit_702.jpgruta: training
# recortando: fruit_704.jpgruta: training
# recortando: fruit_705.jpgruta: training
# recortando: fruit_706.jpgruta: training
# recortando: fruit_707.jpgruta: training
# recortando: fruit_708.jpgruta: training
# recortando: fruit_709.jpgruta: training
# recortando: fruit_71.jpgruta: training
# recortando: fruit_710.jpgruta: training
# recortando: fruit_711.jpgruta: training
# recortando: fruit_712.jpgruta: training
# recortando: fruit_713.jpgruta: training
# recortando: fruit_714.jpgruta: training
# recortando: fruit_715.jpgruta: training
# recortando: fruit_716.jpgruta: training
# recortando: fruit_717.jpgruta: training
# recortando: fruit_718.jpgruta: training
# recortando: fruit_719.jpgruta: training
# recortando: fruit_72.jpgruta: training
# recortando: fruit_720.jpgruta: training
# recortando: fruit_722.jpgruta: training
# recortando: fruit_723.jpgruta: training
# recortando: fruit_726.jpgruta: training
# recortando: fruit_728.jpgruta: training
# recortando: fruit_729.jpgruta: training
# recortando: fruit_73.jpgruta: training
# recortando: fruit_730.jpgruta: training
# recortando: fruit_731.jpgruta: training
# recortando: fruit_732.jpgruta: training
# recortando: fruit_734.jpgruta: training
# recortando: fruit_737.jpgruta: training
# recortando: fruit_738.jpgruta: training
# recortando: fruit_739.jpgruta: training
# recortando: fruit_74.jpgruta: training
# recortando: fruit_740.jpgruta: training
# recortando: fruit_741.jpgruta: training
# recortando: fruit_743.jpgruta: training
# recortando: fruit_745.jpgruta: training
# recortando: fruit_746.jpgruta: training
# recortando: fruit_747.jpgruta: training
# recortando: fruit_749.jpgruta: training
# recortando: fruit_75.jpgruta: training
# recortando: fruit_750.jpgruta: training
# recortando: fruit_751.jpgruta: training
# recortando: fruit_752.jpgruta: training
# recortando: fruit_753.jpgruta: training
# recortando: fruit_754.jpgruta: training
# recortando: fruit_755.jpgruta: training
# recortando: fruit_757.jpgruta: training
# recortando: fruit_758.jpgruta: training
# recortando: fruit_759.jpgruta: training
# recortando: fruit_76.jpgruta: training
# recortando: fruit_761.jpgruta: training
# recortando: fruit_762.jpgruta: training
# recortando: fruit_763.jpgruta: training
# recortando: fruit_765.jpgruta: training
# recortando: fruit_766.jpgruta: training
# recortando: fruit_767.jpgruta: training
# recortando: fruit_768.jpgruta: training
# recortando: fruit_769.jpgruta: training
# recortando: fruit_77.jpgruta: training
# recortando: fruit_770.jpgruta: training
# recortando: fruit_771.jpgruta: training
# recortando: fruit_773.jpgruta: training
# recortando: fruit_774.jpgruta: training
# recortando: fruit_775.jpgruta: training
# recortando: fruit_776.jpgruta: training
# recortando: fruit_777.jpgruta: training
# recortando: fruit_778.jpgruta: training
# recortando: fruit_779.jpgruta: training
# recortando: fruit_78.jpgruta: training
# recortando: fruit_780.jpgruta: training
# recortando: fruit_781.jpgruta: training
# recortando: fruit_782.jpgruta: training
# recortando: fruit_783.jpgruta: training
# recortando: fruit_785.jpgruta: training
# recortando: fruit_786.jpgruta: training
# recortando: fruit_788.jpgruta: training
# recortando: fruit_789.jpgruta: training
# recortando: fruit_79.jpgruta: training
# recortando: fruit_790.jpgruta: training
# recortando: fruit_791.jpgruta: training
# recortando: fruit_792.jpgruta: training
# recortando: fruit_793.jpgruta: training
# recortando: fruit_796.jpgruta: training
# recortando: fruit_798.jpgruta: training
# recortando: fruit_799.jpgruta: training
# recortando: fruit_8.jpgruta: training
# recortando: fruit_80.jpgruta: training
# recortando: fruit_800.jpgruta: training
# recortando: fruit_801.jpgruta: training
# recortando: fruit_802.jpgruta: training
# recortando: fruit_803.jpgruta: training
# recortando: fruit_805.jpgruta: training
# recortando: fruit_806.jpgruta: training
# recortando: fruit_807.jpgruta: training
# recortando: fruit_808.jpgruta: training
# recortando: fruit_809.jpgruta: training
# recortando: fruit_81.jpgruta: training
# recortando: fruit_810.jpgruta: training
# recortando: fruit_812.jpgruta: training
# recortando: fruit_813.jpgruta: training
# recortando: fruit_814.jpgruta: training
# recortando: fruit_816.jpgruta: training
# recortando: fruit_817.jpgruta: training
# recortando: fruit_819.jpgruta: training
# recortando: fruit_820.jpgruta: training
# recortando: fruit_821.jpgruta: training
# recortando: fruit_822.jpgruta: training
# recortando: fruit_823.jpgruta: training
# recortando: fruit_824.jpgruta: training
# recortando: fruit_825.jpgruta: training
# recortando: fruit_826.jpgruta: training
# recortando: fruit_827.jpgruta: training
# recortando: fruit_828.jpgruta: training
# recortando: fruit_831.jpgruta: training
# recortando: fruit_833.jpgruta: training
# recortando: fruit_834.jpgruta: training
# recortando: fruit_835.jpgruta: training
# recortando: fruit_836.jpgruta: training
# recortando: fruit_837.jpgruta: training
# recortando: fruit_839.jpgruta: training
# recortando: fruit_84.jpgruta: training
# recortando: fruit_840.jpgruta: training
# recortando: fruit_841.jpgruta: training
# recortando: fruit_842.jpgruta: training
# recortando: fruit_843.jpgruta: training
# recortando: fruit_844.jpgruta: training
# recortando: fruit_845.jpgruta: training
# recortando: fruit_846.jpgruta: training
# recortando: fruit_847.jpgruta: training
# recortando: fruit_848.jpgruta: training
# recortando: fruit_849.jpgruta: training
# recortando: fruit_85.jpgruta: training
# recortando: fruit_850.jpgruta: training
# recortando: fruit_851.jpgruta: training
# recortando: fruit_852.jpgruta: training
# recortando: fruit_853.jpgruta: training
# recortando: fruit_854.jpgruta: training
# recortando: fruit_855.jpgruta: training
# recortando: fruit_856.jpgruta: training
# recortando: fruit_857.jpgruta: training
# recortando: fruit_858.jpgruta: training
# recortando: fruit_86.jpgruta: training
# recortando: fruit_860.jpgruta: training
# recortando: fruit_861.jpgruta: training
# recortando: fruit_863.jpgruta: training
# recortando: fruit_864.jpgruta: training
# recortando: fruit_865.jpgruta: training
# recortando: fruit_866.jpgruta: training
# recortando: fruit_867.jpgruta: training
# recortando: fruit_868.jpgruta: training
# recortando: fruit_869.jpgruta: training
# recortando: fruit_870.jpgruta: training
# recortando: fruit_872.jpgruta: training
# recortando: fruit_873.jpgruta: training
# recortando: fruit_874.jpgruta: training
# recortando: fruit_875.jpgruta: training
# recortando: fruit_877.jpgruta: training
# recortando: fruit_878.jpgruta: training
# recortando: fruit_879.jpgruta: training
# recortando: fruit_880.jpgruta: training
# recortando: fruit_881.jpgruta: training
# recortando: fruit_884.jpgruta: training
# recortando: fruit_885.jpgruta: training
# recortando: fruit_886.jpgruta: training
# recortando: fruit_887.jpgruta: training
# recortando: fruit_889.jpgruta: training
# recortando: fruit_89.jpgruta: training
# recortando: fruit_890.jpgruta: training
# recortando: fruit_892.jpgruta: training
# recortando: fruit_893.jpgruta: training
# recortando: fruit_894.jpgruta: training
# recortando: fruit_895.jpgruta: training
# recortando: fruit_898.jpgruta: training
# recortando: fruit_899.jpgruta: training
# recortando: fruit_9.jpgruta: training
# recortando: fruit_90.jpgruta: training
# recortando: fruit_900.jpgruta: training
# recortando: fruit_901.jpgruta: training
# recortando: fruit_902.jpgruta: training
# recortando: fruit_903.jpgruta: training
# recortando: fruit_904.jpgruta: training
# recortando: fruit_905.jpgruta: training
# recortando: fruit_906.jpgruta: training
# recortando: fruit_907.jpgruta: training
# recortando: fruit_908.jpgruta: training
# recortando: fruit_909.jpgruta: training
# recortando: fruit_91.jpgruta: training
# recortando: fruit_910.jpgruta: training
# recortando: fruit_911.jpgruta: training
# recortando: fruit_912.jpgruta: training
# recortando: fruit_913.jpgruta: training
# recortando: fruit_914.jpgruta: training
# recortando: fruit_915.jpgruta: training
# recortando: fruit_916.jpgruta: training
# recortando: fruit_917.jpgruta: training
# recortando: fruit_919.jpgruta: training
# recortando: fruit_92.jpgruta: training
# recortando: fruit_922.jpgruta: training
# recortando: fruit_923.jpgruta: training
# recortando: fruit_924.jpgruta: training
# recortando: fruit_925.jpgruta: training
# recortando: fruit_926.jpgruta: training
# recortando: fruit_928.jpgruta: training
# recortando: fruit_929.jpgruta: training
# recortando: fruit_931.jpgruta: training
# recortando: fruit_934.jpgruta: training
# recortando: fruit_935.jpgruta: training
# recortando: fruit_936.jpgruta: training
# recortando: fruit_937.jpgruta: training
# recortando: fruit_938.jpgruta: training
# recortando: fruit_939.jpgruta: training
# recortando: fruit_94.jpgruta: training
# recortando: fruit_940.jpgruta: training
# recortando: fruit_941.jpgruta: training
# recortando: fruit_943.jpgruta: training
# recortando: fruit_944.jpgruta: training
# recortando: fruit_945.jpgruta: training
# recortando: fruit_946.jpgruta: training
# recortando: fruit_947.jpgruta: training
# recortando: fruit_948.jpgruta: training
# recortando: fruit_949.jpgruta: training
# recortando: fruit_95.jpgruta: training
# recortando: fruit_950.jpgruta: training
# recortando: fruit_951.jpgruta: training
# recortando: fruit_952.jpgruta: training
# recortando: fruit_953.jpgruta: training
# recortando: fruit_954.jpgruta: training
# recortando: fruit_956.jpgruta: training
# recortando: fruit_957.jpgruta: training
# recortando: fruit_958.jpgruta: training
# recortando: fruit_959.jpgruta: training
# recortando: fruit_96.jpgruta: training
# recortando: fruit_961.jpgruta: training
# recortando: fruit_962.jpgruta: training
# recortando: fruit_963.jpgruta: training
# recortando: fruit_965.jpgruta: training
# recortando: fruit_966.jpgruta: training
# recortando: fruit_967.jpgruta: training
# recortando: fruit_968.jpgruta: training
# recortando: fruit_97.jpgruta: training
# recortando: fruit_970.jpgruta: training
# recortando: fruit_971.jpgruta: training
# recortando: fruit_972.jpgruta: training
# recortando: fruit_973.jpgruta: training
# recortando: fruit_974.jpgruta: training
# recortando: fruit_975.jpgruta: training
# recortando: fruit_976.jpgruta: training
# recortando: fruit_977.jpgruta: training
# recortando: fruit_978.jpgruta: training
# recortando: fruit_979.jpgruta: training
# recortando: fruit_98.jpgruta: training
# recortando: fruit_980.jpgruta: training
# recortando: fruit_982.jpgruta: training
# recortando: fruit_983.jpgruta: training
# recortando: fruit_984.jpgruta: training
# recortando: fruit_986.jpgruta: training
# recortando: fruit_987.jpgruta: training
# recortando: fruit_988.jpgruta: training
# recortando: fruit_99.jpgruta: training
# recortando: fruit_990.jpgruta: training
# recortando: fruit_991.jpgruta: training
# recortando: fruit_993.jpgruta: training
# recortando: fruit_994.jpgruta: training
# recortando: fruit_995.jpgruta: training
# recortando: fruit_996.jpgruta: training
# recortando: fruit_998.jpgruta: training
# recortando: fruit_999.jpgruta: training
# Proceso de renombrado correcto :)
# ['fruit_1.jpg', 'fruit_10.jpg', 'fruit_1001.jpg', 'fruit_1002.jpg', 'fruit_101.jpg', 'fruit_103.jpg', 'fruit_105.jpg', 'fruit_106.jpg', 'fruit_107.jpg', 'fruit_108.jpg', 'fruit_109.jpg', 'fruit_11.jpg', 'fruit_110.jpg', 'fruit_111.jpg', 'fruit_112.jpg', 'fruit_115.jpg', 'fruit_116.jpg', 'fruit_117.jpg', 'fruit_118.jpg', 'fruit_119.jpg', 'fruit_120.jpg', 'fruit_121.jpg', 'fruit_122.jpg', 'fruit_123.jpg', 'fruit_124.jpg', 'fruit_125.jpg', 'fruit_126.jpg', 'fruit_127.jpg', 'fruit_129.jpg', 'fruit_13.jpg', 'fruit_130.jpg', 'fruit_131.jpg', 'fruit_132.jpg', 'fruit_133.jpg', 'fruit_134.jpg', 'fruit_138.jpg', 'fruit_139.jpg', 'fruit_14.jpg', 'fruit_140.jpg', 'fruit_141.jpg', 'fruit_142.jpg', 'fruit_144.jpg', 'fruit_145.jpg', 'fruit_146.jpg', 'fruit_147.jpg', 'fruit_148.jpg', 'fruit_15.jpg', 'fruit_150.jpg', 'fruit_151.jpg', 'fruit_152.jpg', 'fruit_153.jpg', 'fruit_154.jpg', 'fruit_156.jpg', 'fruit_157.jpg', 'fruit_159.jpg', 'fruit_16.jpg', 'fruit_161.jpg', 'fruit_162.jpg', 'fruit_164.jpg', 'fruit_165.jpg', 'fruit_167.jpg', 'fruit_168.jpg', 'fruit_169.jpg', 'fruit_17.jpg', 'fruit_171.jpg', 'fruit_172.jpg', 'fruit_173.jpg', 'fruit_174.jpg', 'fruit_175.jpg', 'fruit_176.jpg', 'fruit_177.jpg', 'fruit_179.jpg', 'fruit_182.jpg', 'fruit_183.jpg', 'fruit_185.jpg', 'fruit_187.jpg', 'fruit_188.jpg', 'fruit_190.jpg', 'fruit_191.jpg', 'fruit_192.jpg', 'fruit_195.jpg', 'fruit_196.jpg', 'fruit_197.jpg', 'fruit_198.jpg', 'fruit_199.jpg', 'fruit_2.jpg', 'fruit_20.jpg', 'fruit_200.jpg', 'fruit_201.jpg', 'fruit_202.jpg', 'fruit_203.jpg', 'fruit_204.jpg', 'fruit_205.jpg', 'fruit_206.jpg', 'fruit_207.jpg', 'fruit_208.jpg', 'fruit_209.jpg', 'fruit_21.jpg', 'fruit_211.jpg', 'fruit_212.jpg', 'fruit_215.jpg', 'fruit_216.jpg', 'fruit_217.jpg', 'fruit_218.jpg', 'fruit_219.jpg', 'fruit_22.jpg', 'fruit_220.jpg', 'fruit_222.jpg', 'fruit_223.jpg', 'fruit_224.jpg', 'fruit_225.jpg', 'fruit_226.jpg', 'fruit_227.jpg', 'fruit_228.jpg', 'fruit_23.jpg', 'fruit_230.jpg', 'fruit_231.jpg', 'fruit_232.jpg', 'fruit_233.jpg', 'fruit_234.jpg', 'fruit_235.jpg', 'fruit_236.jpg', 'fruit_237.jpg', 'fruit_239.jpg', 'fruit_24.jpg', 'fruit_241.jpg', 'fruit_242.jpg', 'fruit_243.jpg', 'fruit_244.jpg', 'fruit_245.jpg', 'fruit_246.jpg', 'fruit_248.jpg', 'fruit_249.jpg', 'fruit_25.jpg', 'fruit_250.jpg', 'fruit_253.jpg', 'fruit_254.jpg', 'fruit_255.jpg', 'fruit_256.jpg', 'fruit_257.jpg', 'fruit_259.jpg', 'fruit_260.jpg', 'fruit_261.jpg', 'fruit_262.jpg', 'fruit_263.jpg', 'fruit_264.jpg', 'fruit_265.jpg', 'fruit_266.jpg', 'fruit_268.jpg', 'fruit_27.jpg', 'fruit_271.jpg', 'fruit_272.jpg', 'fruit_273.jpg', 'fruit_274.jpg', 'fruit_276.jpg', 'fruit_277.jpg', 'fruit_279.jpg', 'fruit_28.jpg', 'fruit_280.jpg', 'fruit_281.jpg', 'fruit_282.jpg', 'fruit_283.jpg', 'fruit_285.jpg', 'fruit_286.jpg', 'fruit_287.jpg', 'fruit_288.jpg', 'fruit_289.jpg', 'fruit_29.jpg', 'fruit_292.jpg', 'fruit_293.jpg', 'fruit_294.jpg', 'fruit_296.jpg', 'fruit_297.jpg', 'fruit_3.jpg', 'fruit_30.jpg', 'fruit_300.jpg', 'fruit_301.jpg', 'fruit_302.jpg', 'fruit_303.jpg', 'fruit_304.jpg', 'fruit_305.jpg', 'fruit_306.jpg', 'fruit_307.jpg', 'fruit_308.jpg', 'fruit_309.jpg', 'fruit_310.jpg', 'fruit_311.jpg', 'fruit_312.jpg', 'fruit_313.jpg', 'fruit_314.jpg', 'fruit_315.jpg', 'fruit_317.jpg', 'fruit_318.jpg', 'fruit_319.jpg', 'fruit_32.jpg', 'fruit_320.jpg', 'fruit_321.jpg', 'fruit_322.jpg', 'fruit_323.jpg', 'fruit_324.jpg', 'fruit_325.jpg', 'fruit_326.jpg', 'fruit_327.jpg', 'fruit_328.jpg', 'fruit_329.jpg', 'fruit_33.jpg', 'fruit_331.jpg', 'fruit_333.jpg', 'fruit_335.jpg', 'fruit_336.jpg', 'fruit_337.jpg', 'fruit_338.jpg', 'fruit_339.jpg', 'fruit_34.jpg', 'fruit_340.jpg', 'fruit_341.jpg', 'fruit_342.jpg', 'fruit_343.jpg', 'fruit_344.jpg', 'fruit_345.jpg', 'fruit_347.jpg', 'fruit_348.jpg', 'fruit_349.jpg', 'fruit_35.jpg', 'fruit_350.jpg', 'fruit_351.jpg', 'fruit_353.jpg', 'fruit_354.jpg', 'fruit_355.jpg', 'fruit_356.jpg', 'fruit_357.jpg', 'fruit_358.jpg', 'fruit_359.jpg', 'fruit_360.jpg', 'fruit_361.jpg', 'fruit_362.jpg', 'fruit_363.j ...
